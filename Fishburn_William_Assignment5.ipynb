# %% [markdown]
# # Module Five Assignment: Cartpole Problem
# Review the code in this notebook and in the score_logger.py file in the *scores* folder (directory). Once you have reviewed the code, return to this notebook and select **Cell** and then **Run All** from the menu bar to run this code. The code takes several minutes to run.

# %%
import random  
import gym  
import numpy as np  
from collections import deque  
from keras.models import Sequential  
from keras.layers import Dense  
from keras.optimizers import Adam  
  
  
from scores.score_logger import ScoreLogger  
  
ENV_NAME = "CartPole-v1"  
  
GAMMA = 0.95  
LEARNING_RATE = 0.001  
  
MEMORY_SIZE = 1000000  
BATCH_SIZE = 20  
  
EXPLORATION_MAX = 1.0  
EXPLORATION_MIN = 0.01  
EXPLORATION_DECAY = 0.995  
  
  
class DQNSolver:  
  
    def __init__(self, observation_space, action_space):  
        self.exploration_rate = EXPLORATION_MAX  
  
        self.action_space = action_space  
        self.memory = deque(maxlen=MEMORY_SIZE)  
  
        self.model = Sequential()  
        self.model.add(Dense(24, input_shape=(observation_space,), activation="relu"))  
        self.model.add(Dense(24, activation="relu"))  
        self.model.add(Dense(self.action_space, activation="linear"))  
        self.model.compile(loss="mse", optimizer=Adam(lr=LEARNING_RATE))  
  
    def remember(self, state, action, reward, next_state, done):  
        self.memory.append((state, action, reward, next_state, done))  
  
    def act(self, state):  
        if np.random.rand() < self.exploration_rate:  
            return random.randrange(self.action_space)  
        q_values = self.model.predict(state)  
        return np.argmax(q_values[0])  
  
    def experience_replay(self):  
        if len(self.memory) < BATCH_SIZE:  
            return  
        batch = random.sample(self.memory, BATCH_SIZE)  
        for state, action, reward, state_next, terminal in batch:  
            q_update = reward  
            if not terminal:  
                q_update = (reward + GAMMA * np.amax(self.model.predict(state_next)[0]))  
            q_values = self.model.predict(state)  
            q_values[0][action] = q_update  
            self.model.fit(state, q_values, verbose=0)  
        self.exploration_rate *= EXPLORATION_DECAY  
        self.exploration_rate = max(EXPLORATION_MIN, self.exploration_rate)  
  
  
def cartpole():  
    env = gym.make(ENV_NAME)  
    score_logger = ScoreLogger(ENV_NAME)  
    observation_space = env.observation_space.shape[0]  
    action_space = env.action_space.n  
    dqn_solver = DQNSolver(observation_space, action_space)  
    run = 0  
    while True:  
        run += 1  
        state = env.reset()  
        state = np.reshape(state, [1, observation_space])  
        step = 0  
        while True:  
            step += 1  
            #env.render()  
            action = dqn_solver.act(state)  
            state_next, reward, terminal, info = env.step(action)  
            reward = reward if not terminal else -reward  
            state_next = np.reshape(state_next, [1, observation_space])  
            dqn_solver.remember(state, action, reward, state_next, terminal)  
            state = state_next  
            if terminal:  
                print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))  
                score_logger.add_score(step, run)  
                break  
            dqn_solver.experience_replay()

# %%
cartpole()
# Out:
# Run: 1, exploration: 1.0, score: 15
# Scores: (min: 15, avg: 15, max: 15)
#
# Run: 2, exploration: 0.9655206468094844, score: 12
# Scores: (min: 12, avg: 13.5, max: 15)
#
# Run: 3, exploration: 0.9091562615825302, score: 13
# Scores: (min: 12, avg: 13.333333333333334, max: 15)
#
# Run: 4, exploration: 0.8348931673187264, score: 18
# Scores: (min: 12, avg: 14.5, max: 18)
#
# Run: 5, exploration: 0.7628626641409962, score: 19
# Scores: (min: 12, avg: 15.4, max: 19)
#
# Run: 6, exploration: 0.7219385759785162, score: 12
# Scores: (min: 12, avg: 14.833333333333334, max: 19)
#
# Run: 7, exploration: 0.6596532430440636, score: 19
# Scores: (min: 12, avg: 15.428571428571429, max: 19)
#
# Run: 8, exploration: 0.6211445383053219, score: 13
# Scores: (min: 12, avg: 15.125, max: 19)
#
# Run: 9, exploration: 0.5238143793828016, score: 35
# Scores: (min: 12, avg: 17.333333333333332, max: 35)
#
# Run: 10, exploration: 0.5032248303978422, score: 9
# Scores: (min: 9, avg: 16.5, max: 35)
#
# Run: 11, exploration: 0.47622912292284103, score: 12
# Scores: (min: 9, avg: 16.09090909090909, max: 35)
#
# Run: 12, exploration: 0.446186062443672, score: 14
# Scores: (min: 9, avg: 15.916666666666666, max: 35)
#
# Run: 13, exploration: 0.4159480862733536, score: 15
# Scores: (min: 9, avg: 15.846153846153847, max: 35)
#
# Run: 14, exploration: 0.3877593341372176, score: 15
# Scores: (min: 9, avg: 15.785714285714286, max: 35)
#
# Run: 15, exploration: 0.3706551064126331, score: 10
# Scores: (min: 9, avg: 15.4, max: 35)
#
# Run: 16, exploration: 0.3543053533848483, score: 10
# Scores: (min: 9, avg: 15.0625, max: 35)
#
# Run: 17, exploration: 0.3403786882983606, score: 9
# Scores: (min: 9, avg: 14.705882352941176, max: 35)
#
# Run: 18, exploration: 0.3237376186352221, score: 11
# Scores: (min: 9, avg: 14.5, max: 35)
#
# Run: 19, exploration: 0.30483872516307353, score: 13
# Scores: (min: 9, avg: 14.421052631578947, max: 35)
#
# Run: 20, exploration: 0.27853872940185365, score: 19
# Scores: (min: 9, avg: 14.65, max: 35)
#
# Run: 21, exploration: 0.2662522686041882, score: 10
# Scores: (min: 9, avg: 14.428571428571429, max: 35)
#
# Run: 22, exploration: 0.24696734223472733, score: 16
# Scores: (min: 9, avg: 14.5, max: 35)
#
# Run: 23, exploration: 0.23607350863684065, score: 10
# Scores: (min: 9, avg: 14.304347826086957, max: 35)
#
# Run: 24, exploration: 0.22340924607110255, score: 12
# Scores: (min: 9, avg: 14.208333333333334, max: 35)
#
# Run: 25, exploration: 0.21036724137609603, score: 13
# Scores: (min: 9, avg: 14.16, max: 35)
#
# Run: 26, exploration: 0.2010878536592394, score: 10
# Scores: (min: 9, avg: 14, max: 35)
#
# Run: 27, exploration: 0.1903004112552766, score: 12
# Scores: (min: 9, avg: 13.925925925925926, max: 35)
#
# Run: 28, exploration: 0.18190617987607657, score: 10
# Scores: (min: 9, avg: 13.785714285714286, max: 35)
#
# Run: 29, exploration: 0.17475600159032884, score: 9
# Scores: (min: 9, avg: 13.620689655172415, max: 35)
#
# Run: 30, exploration: 0.16704744067563246, score: 10
# Scores: (min: 9, avg: 13.5, max: 35)
#
# Run: 31, exploration: 0.15967890763313974, score: 10
# Scores: (min: 9, avg: 13.387096774193548, max: 35)
#
# Run: 32, exploration: 0.1526354036900377, score: 10
# Scores: (min: 9, avg: 13.28125, max: 35)
#
# Run: 33, exploration: 0.1451730787173275, score: 11
# Scores: (min: 9, avg: 13.212121212121213, max: 35)
#
# Run: 34, exploration: 0.13946676683816583, score: 9
# Scores: (min: 9, avg: 13.088235294117647, max: 35)
#
# Run: 35, exploration: 0.13331482894782642, score: 10
# Scores: (min: 9, avg: 13, max: 35)
#
# Run: 36, exploration: 0.12743425563174798, score: 10
# Scores: (min: 9, avg: 12.916666666666666, max: 35)
#
# Run: 37, exploration: 0.11999500148501063, score: 13
# Scores: (min: 9, avg: 12.91891891891892, max: 35)
#
# Run: 38, exploration: 0.11412846151764894, score: 11
# Scores: (min: 9, avg: 12.868421052631579, max: 35)
#
# Run: 39, exploration: 0.10909420695870241, score: 10
# Scores: (min: 9, avg: 12.794871794871796, max: 35)
#
# Run: 40, exploration: 0.1032418023864836, score: 12
# Scores: (min: 9, avg: 12.775, max: 35)
#
# Run: 41, exploration: 0.09918368135888474, score: 9
# Scores: (min: 9, avg: 12.682926829268293, max: 35)
#
# Run: 42, exploration: 0.09108200798387568, score: 18
# Scores: (min: 9, avg: 12.80952380952381, max: 35)
#
# Run: 43, exploration: 0.08239373898667031, score: 21
# Scores: (min: 9, avg: 13, max: 35)
#
# Run: 44, exploration: 0.07566352740075044, score: 18
# Scores: (min: 9, avg: 13.113636363636363, max: 35)
#
# Run: 45, exploration: 0.06810378976195819, score: 22
# Scores: (min: 9, avg: 13.311111111111112, max: 35)
#
# Run: 46, exploration: 0.06380744126877576, score: 14
# Scores: (min: 9, avg: 13.326086956521738, max: 35)
#
# Run: 47, exploration: 0.05918580250061433, score: 16
# Scores: (min: 9, avg: 13.382978723404255, max: 35)
#
# Run: 48, exploration: 0.05489891379418004, score: 16
# Scores: (min: 9, avg: 13.4375, max: 35)
#
# Run: 49, exploration: 0.04966213277390804, score: 21
# Scores: (min: 9, avg: 13.591836734693878, max: 35)
#
# Run: 50, exploration: 0.04251487140556204, score: 32
# Scores: (min: 9, avg: 13.96, max: 35)
#
# Run: 51, exploration: 0.036033175291307735, score: 34
# Scores: (min: 9, avg: 14.352941176470589, max: 35)
#
# Run: 52, exploration: 0.03038696179137978, score: 35
# Scores: (min: 9, avg: 14.75, max: 35)
#
# Run: 53, exploration: 0.017332943577287888, score: 113
# Scores: (min: 9, avg: 16.60377358490566, max: 113)
#
# Run: 54, exploration: 0.013626370684745774, score: 49
# Scores: (min: 9, avg: 17.203703703703702, max: 113)
#
# Run: 55, exploration: 0.010137759008060509, score: 60
# Scores: (min: 9, avg: 17.98181818181818, max: 113)
#
# Run: 56, exploration: 0.01, score: 123
# Scores: (min: 9, avg: 19.857142857142858, max: 123)
#
# Run: 57, exploration: 0.01, score: 51
# Scores: (min: 9, avg: 20.403508771929825, max: 123)
#
# Run: 58, exploration: 0.01, score: 19
# Scores: (min: 9, avg: 20.379310344827587, max: 123)
#
# Run: 59, exploration: 0.01, score: 50
# Scores: (min: 9, avg: 20.88135593220339, max: 123)
#
# Run: 60, exploration: 0.01, score: 60
# Scores: (min: 9, avg: 21.533333333333335, max: 123)
#
# Run: 61, exploration: 0.01, score: 39
# Scores: (min: 9, avg: 21.81967213114754, max: 123)
#
# Run: 62, exploration: 0.01, score: 41
# Scores: (min: 9, avg: 22.129032258064516, max: 123)
#
# Run: 63, exploration: 0.01, score: 51
# Scores: (min: 9, avg: 22.58730158730159, max: 123)
#
# Run: 64, exploration: 0.01, score: 24
# Scores: (min: 9, avg: 22.609375, max: 123)
#
# Run: 65, exploration: 0.01, score: 33
# Scores: (min: 9, avg: 22.76923076923077, max: 123)
#
# Run: 66, exploration: 0.01, score: 82
# Scores: (min: 9, avg: 23.666666666666668, max: 123)
#
# Run: 67, exploration: 0.01, score: 32
# Scores: (min: 9, avg: 23.791044776119403, max: 123)
#
# Run: 68, exploration: 0.01, score: 120
# Scores: (min: 9, avg: 25.205882352941178, max: 123)
#
# Run: 69, exploration: 0.01, score: 36
# Scores: (min: 9, avg: 25.36231884057971, max: 123)
#
# Run: 70, exploration: 0.01, score: 38
# Scores: (min: 9, avg: 25.542857142857144, max: 123)
#
# Run: 71, exploration: 0.01, score: 38
# Scores: (min: 9, avg: 25.718309859154928, max: 123)
#
# Run: 72, exploration: 0.01, score: 64
# Scores: (min: 9, avg: 26.25, max: 123)
#
# Run: 73, exploration: 0.01, score: 57
# Scores: (min: 9, avg: 26.671232876712327, max: 123)
#
# Run: 74, exploration: 0.01, score: 69
# Scores: (min: 9, avg: 27.243243243243242, max: 123)
#
# Run: 75, exploration: 0.01, score: 63
# Scores: (min: 9, avg: 27.72, max: 123)
#
# Run: 76, exploration: 0.01, score: 112
# Scores: (min: 9, avg: 28.82894736842105, max: 123)
#
# Run: 77, exploration: 0.01, score: 84
# Scores: (min: 9, avg: 29.545454545454547, max: 123)
#
# Run: 78, exploration: 0.01, score: 88
# Scores: (min: 9, avg: 30.294871794871796, max: 123)
#
# Run: 79, exploration: 0.01, score: 190
# Scores: (min: 9, avg: 32.31645569620253, max: 190)
#
# Run: 80, exploration: 0.01, score: 132
# Scores: (min: 9, avg: 33.5625, max: 190)
#
# Run: 81, exploration: 0.01, score: 131
# Scores: (min: 9, avg: 34.76543209876543, max: 190)
#
# Run: 82, exploration: 0.01, score: 256
# Scores: (min: 9, avg: 37.46341463414634, max: 256)
#
# Run: 83, exploration: 0.01, score: 212
# Scores: (min: 9, avg: 39.566265060240966, max: 256)
#
# Run: 84, exploration: 0.01, score: 214
# Scores: (min: 9, avg: 41.642857142857146, max: 256)
#
# Run: 85, exploration: 0.01, score: 178
# Scores: (min: 9, avg: 43.247058823529414, max: 256)
#
# Run: 86, exploration: 0.01, score: 190
# Scores: (min: 9, avg: 44.95348837209303, max: 256)
#
# Run: 87, exploration: 0.01, score: 149
# Scores: (min: 9, avg: 46.14942528735632, max: 256)
#
# Run: 88, exploration: 0.01, score: 184
# Scores: (min: 9, avg: 47.71590909090909, max: 256)
#
# Run: 89, exploration: 0.01, score: 133
# Scores: (min: 9, avg: 48.674157303370784, max: 256)
#
# Run: 90, exploration: 0.01, score: 139
# Scores: (min: 9, avg: 49.67777777777778, max: 256)
#
# Run: 91, exploration: 0.01, score: 158
# Scores: (min: 9, avg: 50.86813186813187, max: 256)
#
# Run: 92, exploration: 0.01, score: 166
# Scores: (min: 9, avg: 52.119565217391305, max: 256)
#
# Run: 93, exploration: 0.01, score: 164
# Scores: (min: 9, avg: 53.32258064516129, max: 256)
#
# Run: 94, exploration: 0.01, score: 181
# Scores: (min: 9, avg: 54.680851063829785, max: 256)
#
# Run: 95, exploration: 0.01, score: 167
# Scores: (min: 9, avg: 55.863157894736844, max: 256)
#
# Run: 96, exploration: 0.01, score: 187
# Scores: (min: 9, avg: 57.229166666666664, max: 256)
#
# Run: 97, exploration: 0.01, score: 161
# Scores: (min: 9, avg: 58.29896907216495, max: 256)
#
# Run: 98, exploration: 0.01, score: 182
# Scores: (min: 9, avg: 59.56122448979592, max: 256)
#
# Run: 99, exploration: 0.01, score: 187
# Scores: (min: 9, avg: 60.84848484848485, max: 256)
#
# Run: 100, exploration: 0.01, score: 236
# Scores: (min: 9, avg: 62.6, max: 256)
#
# Run: 101, exploration: 0.01, score: 169
# Scores: (min: 9, avg: 64.14, max: 256)
#
# Run: 102, exploration: 0.01, score: 183
# Scores: (min: 9, avg: 65.85, max: 256)
#
# Run: 103, exploration: 0.01, score: 168
# Scores: (min: 9, avg: 67.4, max: 256)
#
# Run: 104, exploration: 0.01, score: 174
# Scores: (min: 9, avg: 68.96, max: 256)
#
# Run: 105, exploration: 0.01, score: 194
# Scores: (min: 9, avg: 70.71, max: 256)
#
# Run: 106, exploration: 0.01, score: 169
# Scores: (min: 9, avg: 72.28, max: 256)
#
# Run: 107, exploration: 0.01, score: 155
# Scores: (min: 9, avg: 73.64, max: 256)
#
# Run: 108, exploration: 0.01, score: 292
# Scores: (min: 9, avg: 76.43, max: 292)
#
# Run: 109, exploration: 0.01, score: 177
# Scores: (min: 9, avg: 77.85, max: 292)
#
# Run: 110, exploration: 0.01, score: 185
# Scores: (min: 9, avg: 79.61, max: 292)
#
# Run: 111, exploration: 0.01, score: 250
# Scores: (min: 9, avg: 81.99, max: 292)
#
# Run: 112, exploration: 0.01, score: 154
# Scores: (min: 9, avg: 83.39, max: 292)
#
# Run: 113, exploration: 0.01, score: 152
# Scores: (min: 9, avg: 84.76, max: 292)
#
# Run: 114, exploration: 0.01, score: 205
# Scores: (min: 9, avg: 86.66, max: 292)
#
# Run: 115, exploration: 0.01, score: 168
# Scores: (min: 9, avg: 88.24, max: 292)
#
# Run: 116, exploration: 0.01, score: 273
# Scores: (min: 9, avg: 90.87, max: 292)
#
# Run: 117, exploration: 0.01, score: 154
# Scores: (min: 9, avg: 92.32, max: 292)
#
# Run: 118, exploration: 0.01, score: 143
# Scores: (min: 9, avg: 93.64, max: 292)
#
# Run: 119, exploration: 0.01, score: 179
# Scores: (min: 9, avg: 95.3, max: 292)
#
# Run: 120, exploration: 0.01, score: 167
# Scores: (min: 9, avg: 96.78, max: 292)
#
# Run: 121, exploration: 0.01, score: 174
# Scores: (min: 9, avg: 98.42, max: 292)
#
# Run: 122, exploration: 0.01, score: 166
# Scores: (min: 9, avg: 99.92, max: 292)
#
# Run: 123, exploration: 0.01, score: 135
# Scores: (min: 9, avg: 101.17, max: 292)
#
# Run: 124, exploration: 0.01, score: 146
# Scores: (min: 9, avg: 102.51, max: 292)
#
# Run: 125, exploration: 0.01, score: 168
# Scores: (min: 9, avg: 104.06, max: 292)
#
# Run: 126, exploration: 0.01, score: 206
# Scores: (min: 9, avg: 106.02, max: 292)
#
# Run: 127, exploration: 0.01, score: 217
# Scores: (min: 9, avg: 108.07, max: 292)
#
# Run: 128, exploration: 0.01, score: 166
# Scores: (min: 9, avg: 109.63, max: 292)
#
# Run: 129, exploration: 0.01, score: 158
# Scores: (min: 9, avg: 111.12, max: 292)
#
# Run: 130, exploration: 0.01, score: 172
# Scores: (min: 9, avg: 112.74, max: 292)
#
# Run: 131, exploration: 0.01, score: 148
# Scores: (min: 9, avg: 114.12, max: 292)
#
# Run: 132, exploration: 0.01, score: 174
# Scores: (min: 9, avg: 115.76, max: 292)
#
# Run: 133, exploration: 0.01, score: 183
# Scores: (min: 9, avg: 117.48, max: 292)
#
# Run: 134, exploration: 0.01, score: 139
# Scores: (min: 9, avg: 118.78, max: 292)
#
# Run: 135, exploration: 0.01, score: 193
# Scores: (min: 9, avg: 120.61, max: 292)
#
# Run: 136, exploration: 0.01, score: 169
# Scores: (min: 9, avg: 122.2, max: 292)
#
# Run: 137, exploration: 0.01, score: 147
# Scores: (min: 9, avg: 123.54, max: 292)
#
# Run: 138, exploration: 0.01, score: 179
# Scores: (min: 9, avg: 125.22, max: 292)
#
# Run: 139, exploration: 0.01, score: 139
# Scores: (min: 9, avg: 126.51, max: 292)
#
# Run: 140, exploration: 0.01, score: 159
# Scores: (min: 9, avg: 127.98, max: 292)
#
# Run: 141, exploration: 0.01, score: 215
# Scores: (min: 14, avg: 130.04, max: 292)
#
# Run: 142, exploration: 0.01, score: 143
# Scores: (min: 14, avg: 131.29, max: 292)
#
# Run: 143, exploration: 0.01, score: 159
# Scores: (min: 14, avg: 132.67, max: 292)
#
# Run: 144, exploration: 0.01, score: 178
# Scores: (min: 14, avg: 134.27, max: 292)
#
# Run: 145, exploration: 0.01, score: 154
# Scores: (min: 14, avg: 135.59, max: 292)
#
# Run: 146, exploration: 0.01, score: 182
# Scores: (min: 16, avg: 137.27, max: 292)
#
# Run: 147, exploration: 0.01, score: 136
# Scores: (min: 16, avg: 138.47, max: 292)
#
# Run: 148, exploration: 0.01, score: 171
# Scores: (min: 19, avg: 140.02, max: 292)
#
# Run: 149, exploration: 0.01, score: 145
# Scores: (min: 19, avg: 141.26, max: 292)
#
# Run: 150, exploration: 0.01, score: 158
# Scores: (min: 19, avg: 142.52, max: 292)
#
# Run: 151, exploration: 0.01, score: 144
# Scores: (min: 19, avg: 143.62, max: 292)
#
# Run: 152, exploration: 0.01, score: 133
# Scores: (min: 19, avg: 144.6, max: 292)
#
# Run: 153, exploration: 0.01, score: 141
# Scores: (min: 19, avg: 144.88, max: 292)
#
# Run: 154, exploration: 0.01, score: 158
# Scores: (min: 19, avg: 145.97, max: 292)
#
# Run: 155, exploration: 0.01, score: 217
# Scores: (min: 19, avg: 147.54, max: 292)
#
# Run: 156, exploration: 0.01, score: 142
# Scores: (min: 19, avg: 147.73, max: 292)
#
# Run: 157, exploration: 0.01, score: 171
# Scores: (min: 19, avg: 148.93, max: 292)
#
# Run: 158, exploration: 0.01, score: 181
# Scores: (min: 24, avg: 150.55, max: 292)
#
# Run: 159, exploration: 0.01, score: 165
# Scores: (min: 24, avg: 151.7, max: 292)
#
# Run: 160, exploration: 0.01, score: 134
# Scores: (min: 24, avg: 152.44, max: 292)
#
# Run: 161, exploration: 0.01, score: 149
# Scores: (min: 24, avg: 153.54, max: 292)
#
# Run: 162, exploration: 0.01, score: 155
# Scores: (min: 24, avg: 154.68, max: 292)
#
# Run: 163, exploration: 0.01, score: 201
# Scores: (min: 24, avg: 156.18, max: 292)
#
# Run: 164, exploration: 0.01, score: 146
# Scores: (min: 32, avg: 157.4, max: 292)
#
# Run: 165, exploration: 0.01, score: 150
# Scores: (min: 32, avg: 158.57, max: 292)
#
# Run: 166, exploration: 0.01, score: 255
# Scores: (min: 32, avg: 160.3, max: 292)
#
# Run: 167, exploration: 0.01, score: 199
# Scores: (min: 36, avg: 161.97, max: 292)
#
# Run: 168, exploration: 0.01, score: 162
# Scores: (min: 36, avg: 162.39, max: 292)
#
# Run: 169, exploration: 0.01, score: 166
# Scores: (min: 38, avg: 163.69, max: 292)
#
# Run: 170, exploration: 0.01, score: 242
# Scores: (min: 38, avg: 165.73, max: 292)
#
# Run: 171, exploration: 0.01, score: 128
# Scores: (min: 57, avg: 166.63, max: 292)
#
# Run: 172, exploration: 0.01, score: 202
# Scores: (min: 57, avg: 168.01, max: 292)
#
# Run: 173, exploration: 0.01, score: 133
# Scores: (min: 63, avg: 168.77, max: 292)
#
# Run: 174, exploration: 0.01, score: 181
# Scores: (min: 63, avg: 169.89, max: 292)
#
# Run: 175, exploration: 0.01, score: 204
# Scores: (min: 84, avg: 171.3, max: 292)
#
# Run: 176, exploration: 0.01, score: 139
# Scores: (min: 84, avg: 171.57, max: 292)
#
# Run: 177, exploration: 0.01, score: 161
# Scores: (min: 88, avg: 172.34, max: 292)
#
# Run: 178, exploration: 0.01, score: 139
# Scores: (min: 128, avg: 172.85, max: 292)
#
# Run: 179, exploration: 0.01, score: 229
# Scores: (min: 128, avg: 173.24, max: 292)
#
# Run: 180, exploration: 0.01, score: 358
# Scores: (min: 128, avg: 175.5, max: 358)
#
# Run: 181, exploration: 0.01, score: 135
# Scores: (min: 128, avg: 175.54, max: 358)
#
# Run: 182, exploration: 0.01, score: 197
# Scores: (min: 128, avg: 174.95, max: 358)
#
# Run: 183, exploration: 0.01, score: 247
# Scores: (min: 128, avg: 175.3, max: 358)
#
# Run: 184, exploration: 0.01, score: 138
# Scores: (min: 128, avg: 174.54, max: 358)
#
# Run: 185, exploration: 0.01, score: 262
# Scores: (min: 128, avg: 175.38, max: 358)
#
# Run: 186, exploration: 0.01, score: 134
# Scores: (min: 128, avg: 174.82, max: 358)
#
# Run: 187, exploration: 0.01, score: 150
# Scores: (min: 128, avg: 174.83, max: 358)
#
# Run: 188, exploration: 0.01, score: 141
# Scores: (min: 128, avg: 174.4, max: 358)
#
# Run: 189, exploration: 0.01, score: 173
# Scores: (min: 128, avg: 174.8, max: 358)
#
# Run: 190, exploration: 0.01, score: 63
# Scores: (min: 63, avg: 174.04, max: 358)
#
# Run: 191, exploration: 0.01, score: 264
# Scores: (min: 63, avg: 175.1, max: 358)
#
# Run: 192, exploration: 0.01, score: 149
# Scores: (min: 63, avg: 174.93, max: 358)
#
# Run: 193, exploration: 0.01, score: 114
# Scores: (min: 63, avg: 174.43, max: 358)
#
# Run: 194, exploration: 0.01, score: 179
# Scores: (min: 63, avg: 174.41, max: 358)
#
# Run: 195, exploration: 0.01, score: 226
# Scores: (min: 63, avg: 175, max: 358)
#
# Run: 196, exploration: 0.01, score: 166
# Scores: (min: 63, avg: 174.79, max: 358)
#
# Run: 197, exploration: 0.01, score: 144
# Scores: (min: 63, avg: 174.62, max: 358)
#
# Run: 198, exploration: 0.01, score: 229
# Scores: (min: 63, avg: 175.09, max: 358)
#
# Run: 199, exploration: 0.01, score: 127
# Scores: (min: 63, avg: 174.49, max: 358)
#
# Run: 200, exploration: 0.01, score: 137
# Scores: (min: 63, avg: 173.5, max: 358)
#
# Run: 201, exploration: 0.01, score: 140
# Scores: (min: 63, avg: 173.21, max: 358)
#
# Run: 202, exploration: 0.01, score: 137
# Scores: (min: 63, avg: 172.75, max: 358)
#
# Run: 203, exploration: 0.01, score: 159
# Scores: (min: 63, avg: 172.66, max: 358)
#
# Run: 204, exploration: 0.01, score: 137
# Scores: (min: 63, avg: 172.29, max: 358)
#
# Run: 205, exploration: 0.01, score: 152
# Scores: (min: 63, avg: 171.87, max: 358)
#
# Run: 206, exploration: 0.01, score: 135
# Scores: (min: 63, avg: 171.53, max: 358)
#
# Run: 207, exploration: 0.01, score: 215
# Scores: (min: 63, avg: 172.13, max: 358)
#
# Run: 208, exploration: 0.01, score: 170
# Scores: (min: 63, avg: 170.91, max: 358)
#
# Run: 209, exploration: 0.01, score: 142
# Scores: (min: 63, avg: 170.56, max: 358)
#
# Run: 210, exploration: 0.01, score: 143
# Scores: (min: 63, avg: 170.14, max: 358)
#
# Run: 211, exploration: 0.01, score: 136
# Scores: (min: 63, avg: 169, max: 358)
#
# Run: 212, exploration: 0.01, score: 150
# Scores: (min: 63, avg: 168.96, max: 358)
#
# Run: 213, exploration: 0.01, score: 248
# Scores: (min: 63, avg: 169.92, max: 358)
#
# Run: 214, exploration: 0.01, score: 148
# Scores: (min: 63, avg: 169.35, max: 358)
#
# Run: 215, exploration: 0.01, score: 259
# Scores: (min: 63, avg: 170.26, max: 358)
#
# Run: 216, exploration: 0.01, score: 146
# Scores: (min: 63, avg: 168.99, max: 358)
#
# Run: 217, exploration: 0.01, score: 200
# Scores: (min: 63, avg: 169.45, max: 358)
#
# Run: 218, exploration: 0.01, score: 148
# Scores: (min: 63, avg: 169.5, max: 358)
#
# Run: 219, exploration: 0.01, score: 154
# Scores: (min: 63, avg: 169.25, max: 358)
#
# Run: 220, exploration: 0.01, score: 230
# Scores: (min: 63, avg: 169.88, max: 358)
#
# Run: 221, exploration: 0.01, score: 191
# Scores: (min: 63, avg: 170.05, max: 358)
#
# Run: 222, exploration: 0.01, score: 182
# Scores: (min: 63, avg: 170.21, max: 358)
#
# Run: 223, exploration: 0.01, score: 210
# Scores: (min: 63, avg: 170.96, max: 358)
#
# Run: 224, exploration: 0.01, score: 153
# Scores: (min: 63, avg: 171.03, max: 358)
#
# Run: 225, exploration: 0.01, score: 227
# Scores: (min: 63, avg: 171.62, max: 358)
#
# Run: 226, exploration: 0.01, score: 239
# Scores: (min: 63, avg: 171.95, max: 358)
#
# Run: 227, exploration: 0.01, score: 227
# Scores: (min: 63, avg: 172.05, max: 358)
#
# Run: 228, exploration: 0.01, score: 160
# Scores: (min: 63, avg: 171.99, max: 358)
#
# Run: 229, exploration: 0.01, score: 189
# Scores: (min: 63, avg: 172.3, max: 358)
#
# Run: 230, exploration: 0.01, score: 180
# Scores: (min: 63, avg: 172.38, max: 358)
#
# Run: 231, exploration: 0.01, score: 287
# Scores: (min: 63, avg: 173.77, max: 358)
#
# Run: 232, exploration: 0.01, score: 219
# Scores: (min: 63, avg: 174.22, max: 358)
#
# Run: 233, exploration: 0.01, score: 149
# Scores: (min: 63, avg: 173.88, max: 358)
#
# Run: 234, exploration: 0.01, score: 201
# Scores: (min: 63, avg: 174.5, max: 358)
#
# Run: 235, exploration: 0.01, score: 187
# Scores: (min: 63, avg: 174.44, max: 358)
#
# Run: 236, exploration: 0.01, score: 208
# Scores: (min: 63, avg: 174.83, max: 358)
#
# Run: 237, exploration: 0.01, score: 131
# Scores: (min: 63, avg: 174.67, max: 358)
#
# Run: 238, exploration: 0.01, score: 216
# Scores: (min: 63, avg: 175.04, max: 358)
#
# Run: 239, exploration: 0.01, score: 230
# Scores: (min: 63, avg: 175.95, max: 358)
#
# Run: 240, exploration: 0.01, score: 216
# Scores: (min: 63, avg: 176.52, max: 358)
#
# Run: 241, exploration: 0.01, score: 218
# Scores: (min: 63, avg: 176.55, max: 358)
#
# Run: 242, exploration: 0.01, score: 216
# Scores: (min: 63, avg: 177.28, max: 358)
#
# Run: 243, exploration: 0.01, score: 199
# Scores: (min: 63, avg: 177.68, max: 358)
#
# Run: 244, exploration: 0.01, score: 206
# Scores: (min: 63, avg: 177.96, max: 358)
#
# Run: 245, exploration: 0.01, score: 250
# Scores: (min: 63, avg: 178.92, max: 358)
#
# Run: 246, exploration: 0.01, score: 128
# Scores: (min: 63, avg: 178.38, max: 358)
#
# Run: 247, exploration: 0.01, score: 138
# Scores: (min: 63, avg: 178.4, max: 358)
#
# Run: 248, exploration: 0.01, score: 188
# Scores: (min: 63, avg: 178.57, max: 358)
#
# Run: 249, exploration: 0.01, score: 208
# Scores: (min: 63, avg: 179.2, max: 358)
#
# Run: 250, exploration: 0.01, score: 323
# Scores: (min: 63, avg: 180.85, max: 358)
#
# Run: 251, exploration: 0.01, score: 176
# Scores: (min: 63, avg: 181.17, max: 358)
#
# Run: 252, exploration: 0.01, score: 151
# Scores: (min: 63, avg: 181.35, max: 358)
#
# Run: 253, exploration: 0.01, score: 125
# Scores: (min: 63, avg: 181.19, max: 358)
#
# Run: 254, exploration: 0.01, score: 246
# Scores: (min: 63, avg: 182.07, max: 358)
#
# Run: 255, exploration: 0.01, score: 235
# Scores: (min: 63, avg: 182.25, max: 358)
#
# Run: 256, exploration: 0.01, score: 279
# Scores: (min: 63, avg: 183.62, max: 358)
#
# Run: 257, exploration: 0.01, score: 186
# Scores: (min: 63, avg: 183.77, max: 358)
#
# Run: 258, exploration: 0.01, score: 264
# Scores: (min: 63, avg: 184.6, max: 358)
#
# Run: 259, exploration: 0.01, score: 335
# Scores: (min: 63, avg: 186.3, max: 358)
#
# Run: 260, exploration: 0.01, score: 260
# Scores: (min: 63, avg: 187.56, max: 358)
#
# Run: 261, exploration: 0.01, score: 302
# Scores: (min: 63, avg: 189.09, max: 358)
#
# Run: 262, exploration: 0.01, score: 108
# Scores: (min: 63, avg: 188.62, max: 358)
#
# Run: 263, exploration: 0.01, score: 136
# Scores: (min: 63, avg: 187.97, max: 358)
#
# Run: 264, exploration: 0.01, score: 255
# Scores: (min: 63, avg: 189.06, max: 358)
#
# Run: 265, exploration: 0.01, score: 237
# Scores: (min: 63, avg: 189.93, max: 358)
#
# Run: 266, exploration: 0.01, score: 29
# Scores: (min: 29, avg: 187.67, max: 358)
#
# Run: 267, exploration: 0.01, score: 136
# Scores: (min: 29, avg: 187.04, max: 358)
#
# Run: 268, exploration: 0.01, score: 206
# Scores: (min: 29, avg: 187.48, max: 358)
#
# Run: 269, exploration: 0.01, score: 164
# Scores: (min: 29, avg: 187.46, max: 358)
#
# Run: 270, exploration: 0.01, score: 133
# Scores: (min: 29, avg: 186.37, max: 358)
#
# Run: 271, exploration: 0.01, score: 147
# Scores: (min: 29, avg: 186.56, max: 358)
#
# Run: 272, exploration: 0.01, score: 133
# Scores: (min: 29, avg: 185.87, max: 358)
#
# Run: 273, exploration: 0.01, score: 146
# Scores: (min: 29, avg: 186, max: 358)
#
# Run: 274, exploration: 0.01, score: 178
# Scores: (min: 29, avg: 185.97, max: 358)
#
# Run: 275, exploration: 0.01, score: 182
# Scores: (min: 29, avg: 185.75, max: 358)
#
# Run: 276, exploration: 0.01, score: 171
# Scores: (min: 29, avg: 186.07, max: 358)
#
# Run: 277, exploration: 0.01, score: 162
# Scores: (min: 29, avg: 186.08, max: 358)
#
# Run: 278, exploration: 0.01, score: 196
# Scores: (min: 29, avg: 186.65, max: 358)
#
# Run: 279, exploration: 0.01, score: 200
# Scores: (min: 29, avg: 186.36, max: 358)
#
# Run: 280, exploration: 0.01, score: 111
# Scores: (min: 29, avg: 183.89, max: 335)
#
# Run: 281, exploration: 0.01, score: 207
# Scores: (min: 29, avg: 184.61, max: 335)
#
# Run: 282, exploration: 0.01, score: 165
# Scores: (min: 29, avg: 184.29, max: 335)
#
# Run: 283, exploration: 0.01, score: 206
# Scores: (min: 29, avg: 183.88, max: 335)
#
# Run: 284, exploration: 0.01, score: 125
# Scores: (min: 29, avg: 183.75, max: 335)
#
# Run: 285, exploration: 0.01, score: 281
# Scores: (min: 29, avg: 183.94, max: 335)
#
# Run: 286, exploration: 0.01, score: 129
# Scores: (min: 29, avg: 183.89, max: 335)
#
# Run: 287, exploration: 0.01, score: 377
# Scores: (min: 29, avg: 186.16, max: 377)
#
# Run: 288, exploration: 0.01, score: 196
# Scores: (min: 29, avg: 186.71, max: 377)
#
# Run: 289, exploration: 0.01, score: 136
# Scores: (min: 29, avg: 186.34, max: 377)
#
# Run: 290, exploration: 0.01, score: 211
# Scores: (min: 29, avg: 187.82, max: 377)
#
# Run: 291, exploration: 0.01, score: 154
# Scores: (min: 29, avg: 186.72, max: 377)
#
# Run: 292, exploration: 0.01, score: 154
# Scores: (min: 29, avg: 186.77, max: 377)
#
# Run: 293, exploration: 0.01, score: 140
# Scores: (min: 29, avg: 187.03, max: 377)
#
# Run: 294, exploration: 0.01, score: 158
# Scores: (min: 29, avg: 186.82, max: 377)
#
# Run: 295, exploration: 0.01, score: 180
# Scores: (min: 29, avg: 186.36, max: 377)
#
# Run: 296, exploration: 0.01, score: 150
# Scores: (min: 29, avg: 186.2, max: 377)
#
# Run: 297, exploration: 0.01, score: 29
# Scores: (min: 29, avg: 185.05, max: 377)
#
# Run: 298, exploration: 0.01, score: 234
# Scores: (min: 29, avg: 185.1, max: 377)
#
# Run: 299, exploration: 0.01, score: 272
# Scores: (min: 29, avg: 186.55, max: 377)
#
# Run: 300, exploration: 0.01, score: 166
# Scores: (min: 29, avg: 186.84, max: 377)
#
# Run: 301, exploration: 0.01, score: 176
# Scores: (min: 29, avg: 187.2, max: 377)
#
# Run: 302, exploration: 0.01, score: 139
# Scores: (min: 29, avg: 187.22, max: 377)
#
# Run: 303, exploration: 0.01, score: 107
# Scores: (min: 29, avg: 186.7, max: 377)
#
# Run: 304, exploration: 0.01, score: 59
# Scores: (min: 29, avg: 185.92, max: 377)
#
# Run: 305, exploration: 0.01, score: 37
# Scores: (min: 29, avg: 184.77, max: 377)
#
# Run: 306, exploration: 0.01, score: 123
# Scores: (min: 29, avg: 184.65, max: 377)
#
# Run: 307, exploration: 0.01, score: 12
# Scores: (min: 12, avg: 182.62, max: 377)
#
# Run: 308, exploration: 0.01, score: 164
# Scores: (min: 12, avg: 182.56, max: 377)
#
# Run: 309, exploration: 0.01, score: 31
# Scores: (min: 12, avg: 181.45, max: 377)
#
# Run: 310, exploration: 0.01, score: 183
# Scores: (min: 12, avg: 181.85, max: 377)
#
# Run: 311, exploration: 0.01, score: 216
# Scores: (min: 12, avg: 182.65, max: 377)
#
# Run: 312, exploration: 0.01, score: 142
# Scores: (min: 12, avg: 182.57, max: 377)
#
# Run: 313, exploration: 0.01, score: 121
# Scores: (min: 12, avg: 181.3, max: 377)
#
# Run: 314, exploration: 0.01, score: 151
# Scores: (min: 12, avg: 181.33, max: 377)
#
# Run: 315, exploration: 0.01, score: 224
# Scores: (min: 12, avg: 180.98, max: 377)
#
# Run: 316, exploration: 0.01, score: 273
# Scores: (min: 12, avg: 182.25, max: 377)
#
# Run: 317, exploration: 0.01, score: 145
# Scores: (min: 12, avg: 181.7, max: 377)
#
# Run: 318, exploration: 0.01, score: 172
# Scores: (min: 12, avg: 181.94, max: 377)
#
# Run: 319, exploration: 0.01, score: 41
# Scores: (min: 12, avg: 180.81, max: 377)
#
# Run: 320, exploration: 0.01, score: 113
# Scores: (min: 12, avg: 179.64, max: 377)
#
# Run: 321, exploration: 0.01, score: 115
# Scores: (min: 12, avg: 178.88, max: 377)
#
# Run: 322, exploration: 0.01, score: 148
# Scores: (min: 12, avg: 178.54, max: 377)
#
# Run: 323, exploration: 0.01, score: 209
# Scores: (min: 12, avg: 178.53, max: 377)
#
# Run: 324, exploration: 0.01, score: 189
# Scores: (min: 12, avg: 178.89, max: 377)
#
# Run: 325, exploration: 0.01, score: 139
# Scores: (min: 12, avg: 178.01, max: 377)
#
# Run: 326, exploration: 0.01, score: 335
# Scores: (min: 12, avg: 178.97, max: 377)
#
# Run: 327, exploration: 0.01, score: 115
# Scores: (min: 12, avg: 177.85, max: 377)
#
# Run: 328, exploration: 0.01, score: 190
# Scores: (min: 12, avg: 178.15, max: 377)
#
# Run: 329, exploration: 0.01, score: 154
# Scores: (min: 12, avg: 177.8, max: 377)
#
# Run: 330, exploration: 0.01, score: 176
# Scores: (min: 12, avg: 177.76, max: 377)
#
# Run: 331, exploration: 0.01, score: 192
# Scores: (min: 12, avg: 176.81, max: 377)
#
# Run: 332, exploration: 0.01, score: 117
# Scores: (min: 12, avg: 175.79, max: 377)
#
# Run: 333, exploration: 0.01, score: 124
# Scores: (min: 12, avg: 175.54, max: 377)
#
# Run: 334, exploration: 0.01, score: 96
# Scores: (min: 12, avg: 174.49, max: 377)
#
# Run: 335, exploration: 0.01, score: 123
# Scores: (min: 12, avg: 173.85, max: 377)
#
# Run: 336, exploration: 0.01, score: 50
# Scores: (min: 12, avg: 172.27, max: 377)
#
# Run: 337, exploration: 0.01, score: 15
# Scores: (min: 12, avg: 171.11, max: 377)
#
# Run: 338, exploration: 0.01, score: 13
# Scores: (min: 12, avg: 169.08, max: 377)
#
# Run: 339, exploration: 0.01, score: 13
# Scores: (min: 12, avg: 166.91, max: 377)
#
# Run: 340, exploration: 0.01, score: 164
# Scores: (min: 12, avg: 166.39, max: 377)
#
# Run: 341, exploration: 0.01, score: 58
# Scores: (min: 12, avg: 164.79, max: 377)
#
# Run: 342, exploration: 0.01, score: 165
# Scores: (min: 12, avg: 164.28, max: 377)
#
# Run: 343, exploration: 0.01, score: 228
# Scores: (min: 12, avg: 164.57, max: 377)
#
# Run: 344, exploration: 0.01, score: 156
# Scores: (min: 12, avg: 164.07, max: 377)
#
# Run: 345, exploration: 0.01, score: 192
# Scores: (min: 12, avg: 163.49, max: 377)
#
# Run: 346, exploration: 0.01, score: 135
# Scores: (min: 12, avg: 163.56, max: 377)
#
# Run: 347, exploration: 0.01, score: 152
# Scores: (min: 12, avg: 163.7, max: 377)
#
# Run: 348, exploration: 0.01, score: 195
# Scores: (min: 12, avg: 163.77, max: 377)
#
# Run: 349, exploration: 0.01, score: 237
# Scores: (min: 12, avg: 164.06, max: 377)
#
# Run: 350, exploration: 0.01, score: 142
# Scores: (min: 12, avg: 162.25, max: 377)
#
# Run: 351, exploration: 0.01, score: 168
# Scores: (min: 12, avg: 162.17, max: 377)
#
# Run: 352, exploration: 0.01, score: 201
# Scores: (min: 12, avg: 162.67, max: 377)
#
# Run: 353, exploration: 0.01, score: 191
# Scores: (min: 12, avg: 163.33, max: 377)
#
# Run: 354, exploration: 0.01, score: 148
# Scores: (min: 12, avg: 162.35, max: 377)
#
# Run: 355, exploration: 0.01, score: 116
# Scores: (min: 12, avg: 161.16, max: 377)
#
# Run: 356, exploration: 0.01, score: 174
# Scores: (min: 12, avg: 160.11, max: 377)
#
# Run: 357, exploration: 0.01, score: 174
# Scores: (min: 12, avg: 159.99, max: 377)
#
# Run: 358, exploration: 0.01, score: 158
# Scores: (min: 12, avg: 158.93, max: 377)
#
# Run: 359, exploration: 0.01, score: 409
# Scores: (min: 12, avg: 159.67, max: 409)
#
# Run: 360, exploration: 0.01, score: 188
# Scores: (min: 12, avg: 158.95, max: 409)
#
# Run: 361, exploration: 0.01, score: 222
# Scores: (min: 12, avg: 158.15, max: 409)
#
# Run: 362, exploration: 0.01, score: 116
# Scores: (min: 12, avg: 158.23, max: 409)
#
# Run: 363, exploration: 0.01, score: 95
# Scores: (min: 12, avg: 157.82, max: 409)
#
# Run: 364, exploration: 0.01, score: 168
# Scores: (min: 12, avg: 156.95, max: 409)
#
# Run: 365, exploration: 0.01, score: 335
# Scores: (min: 12, avg: 157.93, max: 409)
#
# Run: 366, exploration: 0.01, score: 393
# Scores: (min: 12, avg: 161.57, max: 409)
#
# Run: 367, exploration: 0.01, score: 209
# Scores: (min: 12, avg: 162.3, max: 409)
#
# Run: 368, exploration: 0.01, score: 265
# Scores: (min: 12, avg: 162.89, max: 409)
#
# Run: 369, exploration: 0.01, score: 232
# Scores: (min: 12, avg: 163.57, max: 409)
#
# Run: 370, exploration: 0.01, score: 226
# Scores: (min: 12, avg: 164.5, max: 409)
#
# Run: 371, exploration: 0.01, score: 128
# Scores: (min: 12, avg: 164.31, max: 409)
#
# Run: 372, exploration: 0.01, score: 342
# Scores: (min: 12, avg: 166.4, max: 409)
#
# Run: 373, exploration: 0.01, score: 244
# Scores: (min: 12, avg: 167.38, max: 409)
#
# Run: 374, exploration: 0.01, score: 199
# Scores: (min: 12, avg: 167.59, max: 409)
#
# Run: 375, exploration: 0.01, score: 301
# Scores: (min: 12, avg: 168.78, max: 409)
#
# Run: 376, exploration: 0.01, score: 111
# Scores: (min: 12, avg: 168.18, max: 409)
#
# Run: 377, exploration: 0.01, score: 164
# Scores: (min: 12, avg: 168.2, max: 409)
#
# Run: 378, exploration: 0.01, score: 206
# Scores: (min: 12, avg: 168.3, max: 409)
#
# Run: 379, exploration: 0.01, score: 68
# Scores: (min: 12, avg: 166.98, max: 409)
#
# Run: 380, exploration: 0.01, score: 143
# Scores: (min: 12, avg: 167.3, max: 409)
#
# Run: 381, exploration: 0.01, score: 30
# Scores: (min: 12, avg: 165.53, max: 409)
#
# Run: 382, exploration: 0.01, score: 41
# Scores: (min: 12, avg: 164.29, max: 409)
#
# Run: 383, exploration: 0.01, score: 124
# Scores: (min: 12, avg: 163.47, max: 409)
#
# Run: 384, exploration: 0.01, score: 100
# Scores: (min: 12, avg: 163.22, max: 409)
#
# Run: 385, exploration: 0.01, score: 185
# Scores: (min: 12, avg: 162.26, max: 409)
#
# Run: 386, exploration: 0.01, score: 500
# Scores: (min: 12, avg: 165.97, max: 500)
#
# Run: 387, exploration: 0.01, score: 500
# Scores: (min: 12, avg: 167.2, max: 500)
#
# Run: 388, exploration: 0.01, score: 149
# Scores: (min: 12, avg: 166.73, max: 500)
#
# Run: 389, exploration: 0.01, score: 211
# Scores: (min: 12, avg: 167.48, max: 500)
#
# Run: 390, exploration: 0.01, score: 175
# Scores: (min: 12, avg: 167.12, max: 500)
#
# Run: 391, exploration: 0.01, score: 130
# Scores: (min: 12, avg: 166.88, max: 500)
#
# Run: 392, exploration: 0.01, score: 287
# Scores: (min: 12, avg: 168.21, max: 500)
#
# Run: 393, exploration: 0.01, score: 96
# Scores: (min: 12, avg: 167.77, max: 500)
#
# Run: 394, exploration: 0.01, score: 150
# Scores: (min: 12, avg: 167.69, max: 500)
#
# Run: 395, exploration: 0.01, score: 126
# Scores: (min: 12, avg: 167.15, max: 500)
#
# Run: 396, exploration: 0.01, score: 166
# Scores: (min: 12, avg: 167.31, max: 500)
#
# Run: 397, exploration: 0.01, score: 125
# Scores: (min: 12, avg: 168.27, max: 500)
#
# Run: 398, exploration: 0.01, score: 253
# Scores: (min: 12, avg: 168.46, max: 500)
#
# Run: 399, exploration: 0.01, score: 496
# Scores: (min: 12, avg: 170.7, max: 500)
#
# Run: 400, exploration: 0.01, score: 243
# Scores: (min: 12, avg: 171.47, max: 500)
#
# Run: 401, exploration: 0.01, score: 201
# Scores: (min: 12, avg: 171.72, max: 500)
#
# Run: 402, exploration: 0.01, score: 164
# Scores: (min: 12, avg: 171.97, max: 500)
#
# Run: 403, exploration: 0.01, score: 225
# Scores: (min: 12, avg: 173.15, max: 500)
#
# Run: 404, exploration: 0.01, score: 115
# Scores: (min: 12, avg: 173.71, max: 500)
#
# Run: 405, exploration: 0.01, score: 108
# Scores: (min: 12, avg: 174.42, max: 500)
#
# Run: 406, exploration: 0.01, score: 103
# Scores: (min: 12, avg: 174.22, max: 500)
#
# Run: 407, exploration: 0.01, score: 500
# Scores: (min: 13, avg: 179.1, max: 500)
#
# Run: 408, exploration: 0.01, score: 200
# Scores: (min: 13, avg: 179.46, max: 500)
#
# Run: 409, exploration: 0.01, score: 500
# Scores: (min: 13, avg: 184.15, max: 500)
#
# Run: 410, exploration: 0.01, score: 268
# Scores: (min: 13, avg: 185, max: 500)
#
# Run: 411, exploration: 0.01, score: 184
# Scores: (min: 13, avg: 184.68, max: 500)
#
# Run: 412, exploration: 0.01, score: 489
# Scores: (min: 13, avg: 188.15, max: 500)
#
# Run: 413, exploration: 0.01, score: 491
# Scores: (min: 13, avg: 191.85, max: 500)
#
# Run: 414, exploration: 0.01, score: 215
# Scores: (min: 13, avg: 192.49, max: 500)
#
# Run: 415, exploration: 0.01, score: 220
# Scores: (min: 13, avg: 192.45, max: 500)
#
# Run: 416, exploration: 0.01, score: 500
# Scores: (min: 13, avg: 194.72, max: 500)
#
# Run: 417, exploration: 0.01, score: 137
# Scores: (min: 13, avg: 194.64, max: 500)
#
# Run: 418, exploration: 0.01, score: 162
# Scores: (min: 13, avg: 194.54, max: 500)
#
# Run: 419, exploration: 0.01, score: 269
# Scores: (min: 13, avg: 196.82, max: 500)
#
# Solved in 319 runs, 419 total runs.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-e23913c48dc8> in <module>
# ----> 1 cartpole()
#
# <ipython-input-8-bea6327a4fd8> in cartpole()
#      84             if terminal:
#      85                 print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))
# ---> 86                 score_logger.add_score(step, run)
#      87                 break
#      88             dqn_solver.experience_replay()
#
# U:\scores\score_logger.py in add_score(self, score, run)
#      52             #               show_trend=False,
#      53             #               show_legend=False)
# ---> 54             exit()
#      55
#      56     def _save_png(self, input_path, output_path, x_label, y_label, average_of_n_last, show_goal, show_trend, show_legend):
#
# NameError: name 'exit' is not defined

# %% [markdown]
# Note: If the code is running properly, you should begin to see output appearing above this code block. It will take several minutes, so it is recommended that you let this code run in the background while completing other work. When the code has finished, it will print output saying, "Solved in _ runs, _ total runs."
#
# You may see an error about not having an exit command. This error does not affect the program's functionality and results from the steps taken to convert the code from Python 2.x to Python 3. Please disregard this error.

# %% [markdown]
# 1. Explain how reinforcement learning concepts apply to the cartpole problem.
# Goal of the Agent:
# The primary goal of the agent in the CartPole problem is to balance a pole on a cart by applying forces to the left or right. The agent must learn to keep the pole upright for as long as possible, maximizing the duration of each episode.
#
# State Values:
# The state of the CartPole environment is represented by a vector consisting of four values:Cart position, Cart velocity, Pole angle, and Pole velocity at the tip; these values provide the agent with information about the current configuration of the cart and pole, allowing it to decide the next action.
#
# Possible Actions:
# -Apply force to the left
# -Apply force to the right
#
# These actions influence the cart's movement and consequently affect the pole's stability.
#
# Reinforcement Algorithm:
# The algorithm used for this problem is Deep Q-Learning. DQN combines Q-Learning with deep neural networks to handle environments with high-dimensional state spaces.
#
# 2. Experience Replay in CartPole
# Function of Experience Replay:
# Experience replay is a technique used to store the agent's experiences (state, action, reward, next state, and done flag) in a replay memory. During training, random samples from it are used to update the Q-values.
#
# Mechanism in the Algorithm:
# In the DQN algorithm, experience replay helps in breaking the correlation between consecutive experiences. By sampling randomly from the replay memory, the agent can learn from a diverse set of past experiences, leading to more stable and efficient learning.
#
# Effect of Discount Factor:
# The discount factor (sybolized by gamma) in reinforcement learning is used to balance the importance of immediate rewards versus future rewards. A higher discount factor places more emphasis on future rewards, encouraging the agent to consider long-term benefits. Conversely, a lower discount factor focuses more on immediate rewards. In this algorithm, the discount factor influences the calculation of the Q-values during training.
#
# 3. Neural Networks in Deep Q-Learning
# Neural Network Architecture:
# The neural network used in the CartPole problem consists of an input layer with 24 neurons (corresponding to the input state), two hidden layers with 24 neurons each, and an output layer with neurons equal to the number of possible actions; in this case there are only two possible actions. The hidden layers use ReLU activation functions and the output layer uses a linear activation function.
#
# Efficiency in Q-Learning:
# The neural network approximates the Q-values for each action given a state, allowing the DQN algorithm to handle large and continuous state spaces. This makes Q-Learning more efficient and applicable to complex problems where traditional Q-Learning would be impractical due to the high-dimensional state space.
#
# Impact of Learning Rate:
# The learning rate , symbolized by the alpha symbol, determines the step size during the gradient descent optimization.
#
# -Increasing the learning rate can speed up the learning process but may lead to instability and divergence if too high.
# -Decreasing the learning rate results in more stable learning but can slow down the convergence.
# -Empirical tuning is needed to find a balance where the learning rate is so it is not too high nor too low.
#
# References
# Sutton, R. S., & Barto, A. G. (2018). Reinforcement Learning: An Introduction. MIT Press.
#
# Mnih, V., et al.(2015). Human-level control through deep reinforcement learning. Nature, 518(7540), 529-533.
